# %% [markdown]
# # Class 1 browser fallback
#
# Use this notebook only when local VS Code/Python setup is unavailable. The records are synthetic.

# %% [markdown]
# ## 1. First run
#
# Before running, locate one text value, one number, one variable name, and one output instruction.

# %%
participant_code = "SYN001"
condition = "gain"

trial_1_ms = 480
trial_2_ms = 510
trial_3_ms = 510

mean_reaction_time_ms = (trial_1_ms + trial_2_ms + trial_3_ms) / 3

print("Participant:", participant_code)
print("Condition:", condition)
print("Mean reaction time (ms):", mean_reaction_time_ms)

# %% [markdown]
# ## 2. Predict, change, rerun
#
# Change trial_2_ms from 510 to 540. Predict the new mean before running. Then restore 510.

# %% [markdown]
# ## 3. Read one error
#
# The next cell intentionally omits quotation marks around gain. Run it, read the final error line, and explain whether gain was intended as text or a variable name.

# %%
condition = gain
print("Condition:", condition)

# %% [markdown]
# Repair the cell by adding quotation marks around gain, then rerun it.

# %% [markdown]
# ## 4. Core practice
#
# Replace the two zero values below with the required calculations. The expected mean is 500.0 and the expected accuracy is 0.67.

# %%
participant_code = "SYN001"
condition = "gain"
trial_1_ms = 480
trial_2_ms = 510
trial_3_ms = 510
correct_trials = 2
total_trials = 3

mean_reaction_time_ms = 0
accuracy_rate = 0

print("Participant:", participant_code)
print("Condition:", condition)
print("Mean reaction time (ms):", mean_reaction_time_ms)
print("Correct trials:", correct_trials, "of", total_trials)
print("Accuracy rate:", accuracy_rate)
